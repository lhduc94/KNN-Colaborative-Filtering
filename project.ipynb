# %% [markdown]
# # KNN Collaborative Filtering.

# %%
# This is a code cell without any tag. You can put convenience code here,
# but it won't be included in any way in the final project.
# For example, to be able to run tests locally in the notebook
# you need to install the following:
# pip install nose
# pip install git+https://github.com/datacamp/ipython_nose
# and then load in the ipython_nose extension like this:
# %load_ext ipython_nose

# %% [markdown]
# This is a markdown cell without any tag. You can put text / TODOs / etc. here
# but it won't be included in any way in the final project.
#
# For example, here is the documentation of the format of a DataCamp Project notebook: https://authoring.datacamp.com/projects/projects-format.html

# %% [markdown]
# ## 1. Giới thiệu (<= 55 chars)

# %% [markdown]
# Collaborative Filtering là một trong những cách tiếp cận để giải bài toán Recommendation.
# Project sử dụng thuật toán KNN để  gợi ý Item cho User
#
# ![](img/eclipse.png)

# %% [markdown]
# Thêm các thư viện cần thiết
# - Thêm thư viện `pandas` với tên `pd`.
# - Thêm thư viện `NearestNeighbors` từ `sklearn.neighbors`
# - One bullet per sub task.
# - At most 4 bullets.

# %% [markdown]
# sử dụng `import` để thêm thư viện và `as` để đổi tên

# %%
#Thêm các thư viện cần thiết
...
...

# %%
#Thêm các thư viện cần thiết
import pandas as pd
from sklearn.neighbors import NearestNeighbors

# %%
# %%nose
# import pandas as pd
# from sklearn.neighbors import NearestNeighbors
# Out:
# No tests found.

# %% [markdown]
# ## 2. Load dữ liệu và xem dữ liệu

# %% [markdown]
# Tập dữ liệu là tập __movie_len-1m__ .
# Các bạn có thể tại về tại [đây](https://grouplens.org/datasets/movielens/1m/).
# Đường dẫn của tập dữ liệu : `datasets/ratings.dat`

# %% [markdown]
# - Sử dụng `pd.read_csv` để load dữ liệu, `sep` được gán bằng `::`, `names` được gán bằng `['UserID','ItemID','Rating','Timestamp']`
# - Xem dữ liệu mẫu bằng lệnh `pd.head()`

# %% [markdown]
# - Sử dụng `pd.read_csv` load dữ liệu tại đường dẫn `datasets/ratings.dat`

# %%
#Load dữ liệu
ratings = pd.read_csv(...,sep=...,names=...)
#Xem dữ liệu mẫu
...
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-c09fe3c00d29> in <module>()
# ----> 1 ratings = pd.read_csv(...,sep=...,names=...)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     422     compression = _infer_compression(filepath_or_buffer, compression)
#     423     filepath_or_buffer, _, compression, should_close = get_filepath_or_buffer(
# --> 424         filepath_or_buffer, encoding, compression)
#     425     kwds['compression'] = compression
#     426
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode)
#     216     if not is_file_like(filepath_or_buffer):
#     217         msg = "Invalid file path or buffer object type: {_type}"
# --> 218         raise ValueError(msg.format(_type=type(filepath_or_buffer)))
#     219
#     220     return filepath_or_buffer, None, compression, False
#
# ValueError: Invalid file path or buffer object type: <class 'ellipsis'>

# %%
#Load dữ liệu
ratings = pd.read_csv('datasets/ratings.dat',sep='::',names=['UserID','ItemID','Rating','Timestamp'])
#Xem dữ liệu mẫu
ratings.head()
# Out:
# /home/duclh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#    UserID  ItemID  Rating  Timestamp
# 0       1    1193       5  978300760
# 1       1     661       3  978302109
# 2       1     914       3  978301968
# 3       1    3408       4  978300275
# 4       1    2355       5  978824291

# %%
# %%nose
#
# def test_ratings_correctly_loaded():
#     correct_ratings = pd.read_csv('datasets/ratings.dat',sep='::',names=['UserID','ItemID','Rating','Timestamp'])
#     try:
#         pd.testing.assert_frame_equal(ratings, correct_ratings)
#     except AssertionError:
#         assert False, "xem lại đã chính xác chưa"
# Out:
# /home/duclh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
# 1/1 tests passed

# %% [markdown]
# ## 3. Xem số lượng ratings và số items

# %% [markdown]
# Xem tập dữ liệu có bao nhiêu ratings và có bao nhiêu items

# %% [markdown]
# - sử dụng `__.shape[0]` để xem số lượng rating
# - sử dụng `__['ItemID'].unique()` để xem danh sách items và gán vào biến `list_items` với lệnh `list(__)`
# - sử dụng `len` để xem số lượng items

# %% [markdown]
# abc abc a

# %%
#Xem số lượng rating
print(...)
#gán danh sách item vào biến lis_items:
list_items = list(...)
# Xem danh sách item
print(list_items[:10])
# Xem số lượng item
print(len(list_items))
# Out:
# Ellipsis
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-ee966350a45e> in <module>()
#       2 print(...)
#       3 #gán danh sách item vào biến lis_items:
# ----> 4 list_items = list(...)
#       5 # Xem danh sách item
#       6 print(list_item[:10])
#
# TypeError: 'ellipsis' object is not iterable

# %%
#Xem số lượng rating
print(ratings.shape[0])
#gán danh sách item vào biến lis_items:
list_items = list(ratings['ItemID'].unique())
# Xem danh sách item
print(list_items)
# Xem số lượng item
print(len(list_items))
# Out:
# 1000209
# [1193, 661, 914, 3408, 2355, 1197, 1287, 2804, 594, 919, 595, 938, 2398, 2918, 1035, 2791, 2687, 2018, 3105, 2797, 2321, 720, 1270, 527, 2340, 48, 1097, 1721, 1545, 745, 2294, 3186, 1566, 588, 1907, 783, 1836, 1022, 2762, 150, 1, 1961, 1962, 2692, 260, 1028, 1029, 1207, 2028, 531, 3114, 608, 1246, 1357, 3068, 1537, 647, 2194, 648, 2268, 2628, 1103, 2916, 3468, 1210, 1792, 1687, 1213, 3578, 2881, 3030, 1217, 434, 2126, 3107, 3108, 3035, 1253, 1610, 292, 2236, 3071, 902, 368, 1259, 3147, 1544, 1293, 1188, 3255, 3256, 3257, 110, 2278, 2490, 1834, 3471, 589, 1690, 3654, 2852, 1945, 982, 1873, 2858, 1225, 515, 442, 2312, 265, 1408, 1084, 3699, 480, 1442, 2067, 1265, 1370, 1801, 1372, 2353, 3334, 2427, 590, 1196, 1552, 736, 1198, 593, 2359, 95, 2717, 2571, 1917, 2396, 3735, 1953, 1597, 3809, 1954, 1955, 235, 1124, 1957, 163, 21, 165, 1090, 380, 2501, 349, 457, 1096, 920, 459, 1527, 3418, 1385, 3451, 3095, 780, 498, 2728, 2002, 1784, 2943, 2006, 318, 1968, 3678, 1244, 356, 1245, 3893, 1247, 3421, 1641, 1394, 3534, 104, 2735, 1431, 3868, 1079, 2997, 1615, 1291, 653, 2167, 1580, 3619, 1049, 1261, 552, 1266, 733, 1378, 1379, 3552, 1304, 2470, 3168, 2617, 3671, 2871, 2115, 1136, 2081, 2951, 1214, 1036, 3702, 2366, 1387, 3527, 1201, 2947, 1240, 2987, 2333, 1175, 39, 288, 2337, 1535, 1392, 1466, 860, 1683, 866, 1684, 2770, 215, 1759, 501, 506, 1250, 3793, 509, 41, 2058, 3799, 47, 2700, 296, 581, 1617, 728, 299, 3079, 2560, 1909, 224, 3728, 229, 6, 3006, 1046, 800, 50, 52, 1191, 1192, 3081, 377, 1268, 3083, 3513, 2428, 2282, 3514, 1554, 1912, 2716, 1485, 2289, 162, 1127, 3016, 2070, 1704, 3163, 2437, 2291, 1635, 1279, 2721, 2723, 1921, 2725, 1923, 2580, 3386, 3744, 968, 896, 3020, 1788, 176, 461, 1429, 2159, 1715, 1643, 3249, 3176, 1719, 2806, 2734, 1649, 321, 2013, 3100, 2952, 1794, 2599,
# %% [markdown]
# The task instructions start with a brief sentence framing the task.
#
# - The specific task instructions go in a bullet point list.
# - One bullet per sub task.
# - At most 4 bullets.
#
# <hr>
#
# Give more info, context, and links to external documentation under the horizontal ruler. The instructions should at most have 600 characters.

# %% [markdown]
# This is a hint the student will get if they click the hint button at the bottom of the instructions. It's the last help the student can get, so make it helpful.
#
# ```
# # Feel free to include links to documentation.
# print("And code snippets in the hint.")
# ```

# %%
# This is the sample code the student will see. It should
# consist of up to 10 lines of code and comments, and the
# student should have to complete at most 5 lines of code.

# Rule of thumb: Each bullet point in @instructions should
# correspond to a comment in the @sample_code

# Indicate missing code with ...
like_this = ...
# or when a line or more is required, like this:
# ... YOUR CODE FOR TASK 4 ...

# %%
# Your solution code. This won't be shown to the student.

# The @solution should mirror the corresponding @sample_code,
# but with the missing parts filled in.
like_this = 'missing part filled in'

# It should consist of up to 10 lines of code and comments 
# and take at most 5 seconds to execute on an average laptop.

# %%
# %%nose
#
# # one or more tests of the students code.
# # The @solution should pass the tests.
# # The purpose of the tests is to try to catch common errors and to
# # give the student a hint on how to resolve these errors.
#
# def test_example():
#     assert like_this == 'missing part filled in', \
#     'The student will see this message if the test fails'

# %% [markdown]
# ## 5. Here goes the title of the fifth task (<= 55 chars)

# %% [markdown]
# Context / background / story / etc. This will show up in the student's notebook. It should at most have 800 characters and/or 3 paragraphs.

# %% [markdown]
# The task instructions start with a brief sentence framing the task.
#
# - The specific task instructions go in a bullet point list.
# - One bullet per sub task.
# - At most 4 bullets.
#
# <hr>
#
# Give more info, context, and links to external documentation under the horizontal ruler. The instructions should at most have 600 characters.

# %% [markdown]
# This is a hint the student will get if they click the hint button at the bottom of the instructions. It's the last help the student can get, so make it helpful.
#
# ```
# # Feel free to include links to documentation.
# print("And code snippets in the hint.")
# ```

# %%
# This is the sample code the student will see. It should
# consist of up to 10 lines of code and comments, and the
# student should have to complete at most 5 lines of code.

# Rule of thumb: Each bullet point in @instructions should
# correspond to a comment in the @sample_code

# Indicate missing code with ...
like_this = ...
# or when a line or more is required, like this:
# ... YOUR CODE FOR TASK 5 ...

# %%
# Your solution code. This won't be shown to the student.

# The @solution should mirror the corresponding @sample_code,
# but with the missing parts filled in.
like_this = 'missing part filled in'

# It should consist of up to 10 lines of code and comments 
# and take at most 5 seconds to execute on an average laptop.

# %%
# %%nose
#
# # one or more tests of the students code.
# # The @solution should pass the tests.
# # The purpose of the tests is to try to catch common errors and to
# # give the student a hint on how to resolve these errors.
#
# def test_example():
#     assert like_this == 'missing part filled in', \
#     'The student will see this message if the test fails'

# %% [markdown]
# ## 6. Here goes the title of the sixth task (<= 55 chars)

# %% [markdown]
# Context / background / story / etc. This will show up in the student's notebook. It should at most have 800 characters and/or 3 paragraphs.

# %% [markdown]
# The task instructions start with a brief sentence framing the task.
#
# - The specific task instructions go in a bullet point list.
# - One bullet per sub task.
# - At most 4 bullets.
#
# <hr>
#
# Give more info, context, and links to external documentation under the horizontal ruler. The instructions should at most have 600 characters.

# %% [markdown]
# This is a hint the student will get if they click the hint button at the bottom of the instructions. It's the last help the student can get, so make it helpful.
#
# ```
# # Feel free to include links to documentation.
# print("And code snippets in the hint.")
# ```

# %%
# This is the sample code the student will see. It should
# consist of up to 10 lines of code and comments, and the
# student should have to complete at most 5 lines of code.

# Rule of thumb: Each bullet point in @instructions should
# correspond to a comment in the @sample_code

# Indicate missing code with ...
like_this = ...
# or when a line or more is required, like this:
# ... YOUR CODE FOR TASK 6 ...

# %%
# Your solution code. This won't be shown to the student.

# The @solution should mirror the corresponding @sample_code,
# but with the missing parts filled in.
like_this = 'missing part filled in'

# It should consist of up to 10 lines of code and comments 
# and take at most 5 seconds to execute on an average laptop.

# %%
# %%nose
#
# # one or more tests of the students code.
# # The @solution should pass the tests.
# # The purpose of the tests is to try to catch common errors and to
# # give the student a hint on how to resolve these errors.
#
# def test_example():
#     assert like_this == 'missing part filled in', \
#     'The student will see this message if the test fails'

# %% [markdown]
# ## 7. Here goes the title of the seventh task (<= 55 chars)

# %% [markdown]
# Context / background / story / etc. This will show up in the student's notebook. It should at most have 800 characters and/or 3 paragraphs.

# %% [markdown]
# The task instructions start with a brief sentence framing the task.
#
# - The specific task instructions go in a bullet point list.
# - One bullet per sub task.
# - At most 4 bullets.
#
# <hr>
#
# Give more info, context, and links to external documentation under the horizontal ruler. The instructions should at most have 600 characters.

# %% [markdown]
# This is a hint the student will get if they click the hint button at the bottom of the instructions. It's the last help the student can get, so make it helpful.
#
# ```
# # Feel free to include links to documentation.
# print("And code snippets in the hint.")
# ```

# %%
# This is the sample code the student will see. It should
# consist of up to 10 lines of code and comments, and the
# student should have to complete at most 5 lines of code.

# Rule of thumb: Each bullet point in @instructions should
# correspond to a comment in the @sample_code

# Indicate missing code with ...
like_this = ...
# or when a line or more is required, like this:
# ... YOUR CODE FOR TASK 7 ...

# %%
# Your solution code. This won't be shown to the student.

# The @solution should mirror the corresponding @sample_code,
# but with the missing parts filled in.
like_this = 'missing part filled in'

# It should consist of up to 10 lines of code and comments 
# and take at most 5 seconds to execute on an average laptop.

# %%
# %%nose
#
# # one or more tests of the students code.
# # The @solution should pass the tests.
# # The purpose of the tests is to try to catch common errors and to
# # give the student a hint on how to resolve these errors.
#
# def test_example():
#     assert like_this == 'missing part filled in', \
#     'The student will see this message if the test fails'

# %% [markdown]
# ## 8. Here goes the title of the eighth task (<= 55 chars)

# %% [markdown]
# Context / background / story / etc. This will show up in the student's notebook. It should at most have 800 characters and/or 3 paragraphs.

# %% [markdown]
# The task instructions start with a brief sentence framing the task.
#
# - The specific task instructions go in a bullet point list.
# - One bullet per sub task.
# - At most 4 bullets.
#
# <hr>
#
# Give more info, context, and links to external documentation under the horizontal ruler. The instructions should at most have 600 characters.

# %% [markdown]
# This is a hint the student will get if they click the hint button at the bottom of the instructions. It's the last help the student can get, so make it helpful.
#
# ```
# # Feel free to include links to documentation.
# print("And code snippets in the hint.")
# ```

# %%
# This is the sample code the student will see. It should
# consist of up to 10 lines of code and comments, and the
# student should have to complete at most 5 lines of code.

# Rule of thumb: Each bullet point in @instructions should
# correspond to a comment in the @sample_code

# Indicate missing code with ...
like_this = ...
# or when a line or more is required, like this:
# ... YOUR CODE FOR TASK 8 ...

# %%
# Your solution code. This won't be shown to the student.

# The @solution should mirror the corresponding @sample_code,
# but with the missing parts filled in.
like_this = 'missing part filled in'

# It should consist of up to 10 lines of code and comments 
# and take at most 5 seconds to execute on an average laptop.

# %%
# %%nose
#
# # one or more tests of the students code.
# # The @solution should pass the tests.
# # The purpose of the tests is to try to catch common errors and to
# # give the student a hint on how to resolve these errors.
#
# def test_example():
#     assert like_this == 'missing part filled in', \
#     'The student will see this message if the test fails'

# %% [markdown]
# *The recommended number of tasks in a DataCamp Project is between 8 and 10, so feel free to add more if necessary. You can't have more than 12 tasks.*
